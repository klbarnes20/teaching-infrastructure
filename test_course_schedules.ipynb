# %%
import pandas as pd
from shared.teaching_model import build_all_sections, build_all_course_schedules, build_master_schedule

schedules = build_all_course_schedules(
    sections_file="data/f2026_sections.csv",
)

rows = []

for schedule in schedules:
    for item in schedule["weeks"]:
        rows.append({
            "Course": schedule["course_code"],
            "Section": schedule["section"],
            "DateValue": item["date"],
            "Date": item["date_str"],
            "Type": item["type"],
            "Week": item.get("week"),
            "Topic": item.get("topic"),
            "Readings": item.get("readings"),
            "Assignments": item.get("assignments"),
            "Time": item.get("class_time"),
            "Location": item.get("location"),
        })

df = pd.DataFrame(rows)

course_code = "MOS 2320"

course_df = (
    df[
        df["Course"].str.replace(" ", "")
        == course_code.replace(" ", "")
    ]
    .sort_values(["Section", "DateValue"])
    .drop(columns=["DateValue"])
    .reset_index(drop=True)
)

course_df
# Out:
# MOS 2320
# RETURN has_midterm: False
# RETURN midterm: {'date': 'NA', 'time': 'NA', 'location': 'TBD'}
# MOS 2320
# RETURN has_midterm: False
# RETURN midterm: {'date': 'NA', 'time': 'NA', 'location': 'TBD'}
# MOS 3321
# RETURN has_midterm: True
# RETURN midterm: {'date': '2026-10-24', 'time': '2 - 4 PM', 'location': 'Kingsmill'}
# MOS 3321
# RETURN has_midterm: True
# RETURN midterm: {'date': '2026-10-24', 'time': '2 - 4 PM', 'location': 'Kingsmill'}
#       Course Section                           Date         Type  Week  \
# 0   MOS 2320     550  Wednesday, September 09, 2026  orientation   NaN
# 1   MOS 2320     550     Monday, September 14, 2026  instruction   1.0
# 2   MOS 2320     550     Monday, September 21, 2026  instruction   2.0
# 3   MOS 2320     550     Monday, September 28, 2026  instruction   3.0
# 4   MOS 2320     550  Wednesday, September 30, 2026     no_class   NaN
# 5   MOS 2320     550       Monday, October 05, 2026  instruction   4.0
# 6   MOS 2320     550       Monday, October 12, 2026      holiday   NaN
# 7   MOS 2320     550       Monday, October 19, 2026  instruction   5.0
# 8   MOS 2320     550       Monday, October 26, 2026  instruction   6.0
# 9   MOS 2320     550      Monday, November 02, 2026  instruction   7.0
# 10  MOS 2320     550      Monday, November 09, 2026  instruction   8.0
# 11  MOS 2320     550      Monday, November 16, 2026  instruction   9.0
# 12  MOS 2320     550      Monday, November 23, 2026  instruction  10.0
# 13  MOS 2320     550      Monday, November 30, 2026  instruction  11.0
# 14  MOS 2320     552  Wednesday, September 09, 2026  orientation   NaN
# 15  MOS 2320     552     Monday, September 14, 2026  instruction   1.0
# 16  MOS 2320     552     Monday, September 21, 2026  instruction   2.0
# 17  MOS 2320     552     Monday, September 28, 2026  instruction   3.0
# 18  MOS 2320     552  Wednesday, September 30, 2026     no_class   NaN
# 19  MOS 2320     552       Monday, October 05, 2026  instruction   4.0
# 20  MOS 2320     552       Monday, October 12, 2026      holiday   NaN
# 21  MOS 2320     552       Monday, October 19, 2026  instruction   5.0
# 22  MOS 2320     552       Monday, October 26, 2026  instruction   6.0
# 23  MOS 2320     552      Monday, November 02, 2026  instruction   7.0
# 24  MOS 2320     552      Monday, November 09, 2026  instruction   8.0
# 25  MOS 2320     552      Monday, November 16, 2026  instruction   9.0
# 26  MOS 2320     552      Monday, November 23, 2026  instruction  10.0
# 27  MOS 2320     552      Monday, November 30, 2026  instruction  11.0
#
#                                                 Topic  \
# 0                                  Course Orientation
# 1   Review course syllabus, Introduce Marketing, E...
# 2   Planning and Developing Marketing Strategies, ...
# 3   Consumer Behaviour, Business to Business (B2B)...
# 4   No Class — National Day for Truth and Reconcil...
# 5   Segmentation, Targeting, & Positioning, Market...
# 6                                        Reading Week
# 7   New Product Development, Product, Branding, & ...
# 8                                   Services, Pricing
# 9                  Integrated Marketing Communication
# 10  Promotion: Advertising, Sales Promotions, Soci...
# 11            Place: Distribution Channels, Retailing
# 12               Special Topics: Big Data & Marketing
# 13                                   Special Topics:
# 14                                 Course Orientation
# 15  Review course syllabus, Introduce Marketing, E...
# 16  Planning and Developing Marketing Strategies, ...
# 17  Consumer Behaviour, Business to Business (B2B)...
# 18  No Class — National Day for Truth and Reconcil...
# 19  Segmentation, Targeting, & Positioning, Market...
# 20                                       Reading Week
# 21  New Product Development, Product, Branding, & ...
# 22                                  Services, Pricing
# 23                 Integrated Marketing Communication
# 24  Promotion: Advertising, Sales Promotions, Soci...
# 25            Place: Distribution Channels, Retailing
# 26               Special Topics: Big Data & Marketing
# 27                                   Special Topics:
#
#                                              Readings  \
# 0                                                None
# 1             [Ch. 1, CMA Code of Ethics & Standards]
# 2                                      [Ch. 2, Ch. 3]
# 3                                      [Ch. 4, Ch. 5]
# 4                                                None
# 5           [Ch. 6, Ch. 7 (pp. 193 - 202, 207 - 221)]
# 6                                                None
# 7                                      [Ch. 8, Ch. 9]
# 8                                    [Ch. 10, Ch. 11]
# 9                                            [Ch. 14]
# 10  [Ch. 15 (pp. 479-500), Appendix 14A (pp. 470-4...
# 11                     [Ch. 12 (pp. 361-382), Ch. 13]
# 12  [Ch. 12 (pp. 382-388), Ch. 7 (pp. 202-207, 221...
# 13                                              [TBA]
# 14                                               None
# 15            [Ch. 1, CMA Code of Ethics & Standards]
# 16                                     [Ch. 2, Ch. 3]
# 17                                     [Ch. 4, Ch. 5]
# 18                                               None
# 19          [Ch. 6, Ch. 7 (pp. 193 - 202, 207 - 221)]
# 20                                               None
# 21                                     [Ch. 8, Ch. 9]
# 22                                   [Ch. 10, Ch. 11]
# 23                                           [Ch. 14]
# 24  [Ch. 15 (pp. 479-500), Appendix 14A (pp. 470-4...
# 25                     [Ch. 12 (pp. 361-382), Ch. 13]
# 26  [Ch. 12 (pp. 382-388), Ch. 7 (pp. 202-207, 221...
# 27                                              [TBA]
#
#                                           Assignments  \
# 0                                                None
# 1                                                  []
# 2                                    [Team Formation]
# 3                                     [Team Memo Due]
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                  []
# 8   [Term Project: Elevator Pitch Due (During class)]
# 9                                                  []
# 10  [Term Project: Recommended Group Discussion of...
# 11                                                 []
# 12                 [Term Project: Marketing Plan Due]
# 13                    [Term Project: Video Pitch Due]
# 14                                               None
# 15                                                 []
# 16                                   [Team Formation]
# 17                                    [Team Memo Due]
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                                 []
# 22  [Term Project: Elevator Pitch Due (During class)]
# 23                                                 []
# 24  [Term Project: Recommended Group Discussion of...
# 25                                                 []
# 26                 [Term Project: Marketing Plan Due]
# 27                    [Term Project: Video Pitch Due]
#
#                                                  Time Location
# 0                                                None     None
# 1   Mondays 11:30 AM - 12:30 PM & Wednesdays 11:30...       A1
# 2   Mondays 11:30 AM - 12:30 PM & Wednesdays 11:30...       A1
# 3   Mondays 11:30 AM - 12:30 PM & Wednesdays 11:30...       A1
# 4                                                None     None
# 5   Mondays 11:30 AM - 12:30 PM & Wednesdays 11:30...       A1
# 6   Mondays 11:30 AM - 12:30 PM & Wednesdays 11:30...       A1
# 7   Mondays 11:30 AM - 12:30 PM & Wednesdays 11:30...       A1
# 8   Mondays 11:30 AM - 12:30 PM & Wednesdays 11:30...       A1
# 9   Mondays 11:30 AM - 12:30 PM & Wednesdays 11:30...       A1
# 10  Mondays 11:30 AM - 12:30 PM & Wednesdays 11:30...       A1
# 11  Mondays 11:30 AM - 12:30 PM & Wednesdays 11:30...       A1
# 12  Mondays 11:30 AM - 12:30 PM & Wednesdays 11:30...       A1
# 13  Mondays 11:30 AM - 12:30 PM & Wednesdays 11:30...       A1
# 14                                               None     None
# 15  Mondays 8:30 AM - 10:30 AM & Wednesdays 8:30 A...     H112
# 16  Mondays 8:30 AM - 10:30 AM & Wednesdays 8:30 A...     H112
# 17  Mondays 8:30 AM - 10:30 AM & Wednesdays 8:30 A...     H112
# 18                                               None     None
# 19  Mondays 8:30 AM - 10:30 AM & Wednesdays 8:30 A...     H112
# 20  Mondays 8:30 AM - 10:30 AM & Wednesdays 8:30 A...     H112
# 21  Mondays 8:30 AM - 10:30 AM & Wednesdays 8:30 A...     H112
# 22  Mondays 8:30 AM - 10:30 AM & Wednesdays 8:30 A...     H112
# 23  Mondays 8:30 AM - 10:30 AM & Wednesdays 8:30 A...     H112
# 24  Mondays 8:30 AM - 10:30 AM & Wednesdays 8:30 A...     H112
# 25  Mondays 8:30 AM - 10:30 AM & Wednesdays 8:30 A...     H112
# 26  Mondays 8:30 AM - 10:30 AM & Wednesdays 8:30 A...     H112
# 27  Mondays 8:30 AM - 10:30 AM & Wednesdays 8:30 A...     H112

# %%
for w in scheduled["weeks"]:
    print(
        w["date_str"],
        "|",
        w["type"],
        "|",
        w.get("week"),
        "|",
        w["topic"],
    )
# Out:
# Tuesday, September 15, 2026 | instruction | 1 | Introduction to Consumer Behaviour
# Tuesday, September 22, 2026 | instruction | 2 | Perception
# Tuesday, September 29, 2026 | instruction | 3 | Motivation & Emotions
# Tuesday, October 06, 2026 | instruction | 4 | The Self, Personality, Values and Lifestyles
# Tuesday, October 13, 2026 | holiday | None | Reading Week
# Tuesday, October 20, 2026 | instruction | 5 | Attitudes—Formation, Change, and Persuasion
# Tuesday, October 27, 2026 | midterm | None | Midterm Exam
# Tuesday, November 03, 2026 | instruction | 6 | Data Analysis Part 1
# Tuesday, November 10, 2026 | instruction | 7 | Decision‐Making
# Tuesday, November 17, 2026 | instruction | 8 | Buying, Using, and Disposing: The Consumer Journey
# Tuesday, November 24, 2026 | instruction | 9 | Cultural Influences on CB
# Tuesday, December 01, 2026 | instruction | 10 | Special Topics / Catch-up / Review
# Tuesday, December 08, 2026 | instruction | 11 | Team Presentations
