# %%
from shared.brightspace import generate_course_info, generate_schedule_page
from shared.teaching_model import build_all_course_terms

course_terms = build_all_course_terms()

course_term = next(
    term
    for term in course_terms
    if term["course_code"].replace(" ", "") == "MOS2320"
)

# Generate the shared course information page
course_info = generate_course_info(course_term)

with open("course_information.html", "w", encoding="utf-8") as f:
    f.write(course_info)

# Generate one schedule page per section
for schedule in course_term["schedules"]:
    html = generate_schedule_page(schedule)

    with open(f"{schedule['course_code']}-schedule_{schedule['section']}.html", "w", encoding="utf-8") as f:
        f.write(html)
    print(schedule["section"])
# Out:
# MOS 2320
# RETURN has_midterm: False
# RETURN midterm: {'date': 'NA', 'time': 'NA', 'location': 'TBD'}
# MOS 2320
# RETURN has_midterm: False
# RETURN midterm: {'date': 'NA', 'time': 'NA', 'location': 'TBD'}
# MOS 3321
# RETURN has_midterm: True
# RETURN midterm: {'date': '2026-10-24', 'time': '2 - 4 PM', 'location': 'Kingsmill'}
# MOS 3321
# RETURN has_midterm: True
# RETURN midterm: {'date': '2026-10-24', 'time': '2 - 4 PM', 'location': 'Kingsmill'}
# 550
# 552

# %%
# Assignments 
from shared.brightspace import render_markdown_files
assignment_files = {
    "Team Memo": "data/courses/mos3321/assignments/team_memo.md",
    "Article Review and Project Proposal":
        "data/courses/mos3321/assignments/article_review.md",
    "Survey Materials": "data/courses/mos3321/assignments/survey_materials.md",
    "Presentation": "data/courses/mos3321/assignments/presentation.md",
    "Presentation Guide": "data/courses/mos3321/assignments/presentation_guide.md",
    "Written Report": "data/courses/mos3321/assignments/written_report.md",
    "written_report_guide": "data/courses/mos3321/assignments/written_report_guide.md",
    "Descriptives": "data/courses/mos3321/assignments/descriptives.md",
    "Inferentials": "data/courses/mos3321/assignments/inferentials.md", 
    "Peer Evaluations": "data/courses/mos3321/assignments/peer_evals.md", 
    "Midterm Exam": "data/courses/mos3321/assignments/midterm_exam.md", 
    "Final Exam": "data/courses/mos3321/assignments/final_exam.md", 
}

rendered = render_markdown_files(assignment_files)

print(rendered["Article Review and Project Proposal"])

# %%
import pandas as pd
from shared.teaching_model import build_all_course_schedules

schedules = build_all_course_schedules(
    sections_file="data/f2026_sections.csv"
)

section_551 = next(
    schedule
    for schedule in schedules
    if (
        schedule["course_code"].replace(" ", "") == "MOS3321"
        and str(schedule["section"]) == "551"
    )
)

existing_dates = {
    item["date"]
    for item in section_551["weeks"]
}

for exception in section_551.get("schedule_exceptions", []):
    if exception.get("type") == "review":
        exception_date = pd.to_datetime(
            exception["date"]
        ).date()

        applicable_sections = [
            str(section)
            for section in exception.get("sections", [])
        ]

        print("Exception:", exception)
        print("Current section:", repr(str(section_551["section"])))
        print("Applicable sections:", applicable_sections)
        print("Date:", exception_date)
        print("Date already present:", exception_date in existing_dates)
        print(
            "Should be added:",
            str(section_551["section"]) in applicable_sections
            and exception_date not in existing_dates
            and not exception.get("consumes_week", True)
        )

# %%
from shared.brightspace import render_week_pages
course_terms = build_all_course_terms()

course_term = next(
    term
    for term in course_terms
    if term["course_code"].replace(" ", "") == "MOS2320"
)

week_pages = render_week_pages(course_term)

print(week_pages)
# Out:
# MOS 2320
# RETURN has_midterm: False
# RETURN midterm: {'date': 'NA', 'time': 'NA', 'location': 'TBD'}
# MOS 2320
# RETURN has_midterm: False
# RETURN midterm: {'date': 'NA', 'time': 'NA', 'location': 'TBD'}
# MOS 3321
# RETURN has_midterm: True
# RETURN midterm: {'date': '2026-10-24', 'time': '2 - 4 PM', 'location': 'Kingsmill'}
# MOS 3321
# RETURN has_midterm: True
# RETURN midterm: {'date': '2026-10-24', 'time': '2 - 4 PM', 'location': 'Kingsmill'}
# dict_keys(['Team Memo', 'Elevator Pitch', 'Written Marketing Plan', 'Video Pitch of Marketing Plan', 'Final Exam', 'Participation'])
#
#     <h2 style="
#         margin-top: 0;
#         margin-bottom: 16px;
#         padding-bottom: 6px;
#         border-bottom: 2px solid #d9d9d9;
#     ">
#         Week 1: Review course syllabus, Introduce Marketing, Ethics and Socially Responsible Marketing
#     </h2>
#     <h3>Lecture & Lab</h3><p><strong>Lecture:</strong> Review course syllabus, Introduce Marketing, Ethics and Socially Responsible Marketing</p><h3>Readings</h3><ul><li>Ch. 1</li><li>CMA Code of Ethics & Standards</li></ul></ul><hr>
#     <h2 style="
#         margin-top: 0;
#         margin-bottom: 16px;
#         padding-bottom: 6px;
#         border-bottom: 2px solid #d9d9d9;
#     ">
#         Week 2: Planning and Developing Marketing Strategies, Analyzing the Market Environment
#     </h2>
#     <h3>Lecture & Lab</h3><p><strong>Lecture:</strong> Planning and Developing Marketing Strategies, Analyzing the Market Environment</p><h3>Readings</h3><ul><li>Ch. 2</li><li>Ch. 3</li></ul><h3>Assignments & Deadlines</h3><ul><li><strong>Team Memo</strong> (Due Sep 25)</li></ul><hr>
#     <h2 style="
#         margin-top: 0;
#         margin-bottom: 16px;
#         padding-bottom: 6px;
#         border-bottom: 2px solid #d9d9d9;
#     ">
#         Week 3: Consumer Behaviour, Business to Business (B2B) Marketing
#     </h2>
#     <h3>Lecture & Lab</h3><p><strong>Lecture:</strong> Consumer Behaviour, Business to Business (B2B) Marketing</p><h3>Readings</h3><ul><li>Ch. 4</li><li>Ch. 5</li></ul></ul><hr>
#     <h2 style="
#         margin-top: 0;
#         margin-bottom: 16px;
#         padding-bottom: 6px;
#         border-bottom: 2px solid #d9d9d9;
#     ">
#         Week 4: Segmentation, Targeting, & Positioning, Market Research
#     </h2>
#     <h3>Lecture & Lab</h3><p><strong>Lecture:</strong> Segmentation, Targeting, & Positioning, Market Research</p><h3>Readings</h3><ul><li>Ch. 6</li><li>Ch. 7 (pp. 193 - 202, 207 - 221)</li></ul></ul><hr>
#     <h2 style="
#         margin-top: 0;
#         margin-bottom: 16px;
#         padding-bottom: 6px;
#         border-bottom: 2px solid #d9d9d9;
#     ">
#         Week 5: New Product Development, Product, Branding, & Packaging Decisions
#     </h2>
#     <h3>Lecture & Lab</h3><p><strong>Lecture:</strong> New Product Development, Product, Branding, & Packaging Decisions</p><h3>Readings</h3><ul><li>Ch. 8</li><li>Ch. 9</li></ul></ul><hr>
#     <h2 style="
#         margin-top: 0;
#         margin-bottom: 16px;
#         padding-bottom: 6px;
#         border-bottom: 2px solid #d9d9d9;
#     ">
#         Week 6: Services, Pricing
#     </h2>
#     <h3>Lecture & Lab</h3><p><strong>Lecture:</strong> Services, Pricing</p><h3>Readings</h3><ul><li>Ch. 10</li><li>Ch. 11</li></ul><h3>Assignments & Deadlines</h3><ul><li><strong>Elevator Pitch</strong> (Due Oct 26)</li></ul><hr>
#     <h2 style="
#         margin-top: 0;
#         margin-bottom: 16px;
#         padding-bottom: 6px;
#         border-bottom: 2px solid #d9d9d9;
#     ">
#         Week 7: Integrated Marketing Communication
#     </h2>
#     <h3>Lecture & Lab</h3><p><strong>Lecture:</strong> Integrated Marketing Communication</p><h3>Readings</h3><ul><li>Ch. 14</li></ul></ul><hr>
#     <h2 style="
#         margin-top: 0;
#         margin-bottom: 16px;
#         padding-bottom: 6px;
#         border-bottom: 2px solid #d9d9d9;
#     ">
#         Week 8: Promotion: Advertising, Sales Promotions, Social/Mobile Marketing
#     </h2>
#     <h3>Lecture & Lab</h3><p><strong>Lecture:</strong> Promotion: Advertising, Sales Promotions, Social/Mobile Marketing</p><p><strong>Lab:</strong> Term Project: Recommended Group Discussion of Term Project Progress</p><h3>Readings</h3><ul><li>Ch. 15 (pp. 479-500)</li><li>Appendix 14A (pp. 470-478)</li></ul></ul><hr>
#     <h2 style="
#         margin-top: 0;
#         margin-bottom: 16px;
#         padding-bottom: 6px;
#         border-bottom: 2px solid #d9d9d9;
#     ">
#         Week 9: Place: Distribution Channels, Retailing
#     </h2>
#     <h3>Lecture & Lab</h3><p><strong>Lecture:</strong> Place: Distribution Channels, Retailing</p><h3>Readings</h3><ul><li>Ch. 12 (pp. 361-382)</li><li>Ch. 13</li></ul></ul><hr>
#     <h2 style="
#         margin-top: 0;
#         margin-bottom: 16px;
#         padding-bottom: 6px;
#         border-bottom: 2px solid #d9d9d9;
#     ">
#         Week 10: Special Topics: Big Data & Marketing
#     </h2>
#     <h3>Lecture & Lab</h3><p><strong>Lecture:</strong> Special Topics: Big Data & Marketing</p><h3>Readings</h3><ul><li>Ch. 12 (pp. 382-388)</li><li>Ch. 7 (pp. 202-207, 221-223)</li></ul><h3>Assignments & Deadlines</h3><ul><li><strong>Written Marketing Plan</strong> (Due Nov 22)</li></ul><hr>
#     <h2 style="
#         margin-top: 0;
#         margin-bottom: 16px;
#         padding-bottom: 6px;
#         border-bottom: 2px solid #d9d9d9;
#     ">
#         Week 11: Special Topics:
#     </h2>
#     <h3>Lecture & Lab</h3><p><strong>Lecture:</strong> Special Topics: </p><h3>Readings</h3><ul><li>TBA</li></ul><h3>Assignments & Deadlines</h3><ul><li><strong>Video Pitch of Marketing Plan</strong> (Due Nov 29)</li></ul><hr>
#     <h2 style="
#         margin-top: 0;
#         margin-bottom: 16px;
#         padding-bottom: 6px;
#         border-bottom: 2px solid #d9d9d9;
#     ">
#         Week 12: Course Integration, Application, and Final Exam Review
#     </h2>
#     <h3>Lecture & Lab</h3><p><strong>Lecture:</strong> Course Integration, Application, and Final Exam Review</p><p><strong>Lab:</strong> Integrated Marketing Strategy Activity</p></ul><hr>

# %%
globals().keys()
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__vsc_ipynb_file__', '_i', '_ii', '_iii', '_i1', 'render_week_pages', '_i2', '_2', '_i3', 'generate_course_info', 'generate_schedule_page', 'build_all_course_terms', 'course_terms', 'course_term', 'course_info', 'f', 'schedule', 'html', '_i4', '_i5'])
