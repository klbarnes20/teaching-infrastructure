# %%
from shared.brightspace import generate_course_info
from shared.schedule_utils import build_all_course_terms

course_terms = build_all_course_terms()

course_term = next(
    term
    for term in course_terms
    if term["course_code"].replace(" ", "") == "MOS3321"
)

html = generate_course_info(course_term)

with open("test.html", "w", encoding="utf-8") as f:
    f.write(html)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       4 course_terms = build_all_course_terms()
#       6 course_term = next(
#       7     term
#       8     for term in course_terms
#       9     if term["course_code"].replace(" ", "") == "MOS3321"
#      10 )
# ---> 12 html = generate_course_info(course_term)
#      14 with open("test.html", "w", encoding="utf-8") as f:
#      15     f.write(html)
#
# File c:\Users\klbar\OneDrive - The University of Western Ontario\Faculty\Teaching Infrastructure\shared\brightspace.py:62, in generate_course_info(course_term)
#      59 parts = []
#      61 for renderer in renderers:
# ---> 62     html = renderer(course_term)
#      63     if html:
#      64         parts.append(html)
#
# File c:\Users\klbar\OneDrive - The University of Western Ontario\Faculty\Teaching Infrastructure\shared\brightspace.py:121, in render_course_basics(course_term)
#     115 html += subsection_heading("Class Meetings")
#     117 html += """
#     118 <table style="border-collapse: collapse; width: 100%;">
#     119 """
# --> 121 html += table_header("Section", "Class Time", "Location")
#     123 for meeting in meetings:
#     124     html += data_row(
#     125         meeting["schedules"],
#     126         meeting["class_time"],
#     127         meeting["location"]
#     128     )
#
# TypeError: table_header() takes from 1 to 2 positional arguments but 3 were given
